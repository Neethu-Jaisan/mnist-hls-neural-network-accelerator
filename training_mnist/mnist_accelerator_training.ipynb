# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
mnist = keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

# %%
model = keras.Sequential([
    keras.layers.Dense(16, activation='relu', input_shape=(784,)),
    keras.layers.Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(
    x_train,
    y_train,
    epochs=5,
    batch_size=64
)
# Out:
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7649 - loss: 0.8314
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9212 - loss: 0.2774
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9336 - loss: 0.2301
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9406 - loss: 0.2094
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9452 - loss: 0.1919

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9343 - loss: 0.2246
# Test accuracy: 0.9416000247001648

# %%
W1, b1 = model.layers[0].get_weights()
W2, b2 = model.layers[1].get_weights()

# %%
np.save("W1.npy", W1)
np.save("b1.npy", b1)
np.save("W2.npy", W2)
np.save("b2.npy", b2)

# %%
from google.colab import files

files.download("W1.npy")
files.download("b1.npy")
files.download("W2.npy")
files.download("b2.npy")

# %%
import numpy as np

W1 = np.load("W1.npy")
b1 = np.load("b1.npy")
W2 = np.load("W2.npy")
b2 = np.load("b2.npy")

def array_to_c(name, arr):
    s = f"float {name}"
    for dim in arr.shape:
        s += f"[{dim}]"
    s += " = {\n"

    if arr.ndim == 1:
        s += ", ".join(map(str, arr))
    else:
        rows = []
        for row in arr:
            rows.append("{" + ", ".join(map(str, row)) + "}")
        s += ",\n".join(rows)

    s += "\n};\n\n"
    return s


c_code = ""
c_code += array_to_c("W1", W1)
c_code += array_to_c("b1", b1)
c_code += array_to_c("W2", W2)
c_code += array_to_c("b2", b2)

with open("weights.h", "w") as f:
    f.write(c_code)

print("weights.h generated")
# Out:
# weights.h generated

# %%
from google.colab import files
files.download("weights.h")

# %%
np.save("test_digit.npy", x_test[0])

# %%
import numpy as np
from tensorflow import keras

mnist = keras.datasets.mnist
(_, _), (x_test, y_test) = mnist.load_data()

# normalize
x_test = x_test / 255.0

# flatten to 784
x_test = x_test.reshape(-1, 784)

# save one sample
np.save("test_digit.npy", x_test[0])

print("Label:", y_test[0])
# Out:
# Label: 7

# %%
import numpy as np

img = np.load("test_digit.npy")

c_array = "float test_input[784] = {\n"

for i in range(784):
    c_array += str(img[i]) + ", "

c_array += "\n};"

print(c_array)
# Out:
# float test_input[784] = {
# ...
